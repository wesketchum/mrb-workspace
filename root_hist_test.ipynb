// %%
TF1* input_func = new TF1("input_func", "1", 0.1, 0.6);

// %%
TCanvas c("c");

// %%
input_func->Draw();
c.Draw();

// %%
TH1D* spectrum = new TH1D("spectrum", "neutrino flux", 10000, 0.1, 0.6);

// %%
spectrum->Add(input_func)
// Out:
// (bool) true

// %%
spectrum->Draw();
c.Draw();
