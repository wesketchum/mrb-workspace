# %% [markdown]
# **Simple setup for uboonecode:**

# %%
source /cvmfs/uboone.opensciencegrid.org/products/setup_uboone.sh
setup uboonecode v07_07_01_02 -qe17:prof
# Out:
# Setting up old larsoft UPS area... /cvmfs/fermilab.opensciencegrid.org/products/larsoft/
# Setting up new larsoft UPS area... /cvmfs/larsoft.opensciencegrid.org/products/
# Setting up uboone UPS area... /cvmfs/uboone.opensciencegrid.org/products/

# %% [markdown]
# **My FHiCL file that I'm looking at:**

# %%
ls $PWD/prodgenie_nue_cc_uniform_flux_uboone.fcl
# Out:
# /uboone/app/users/wketchum/dev_areas/mcc9_devs/nue_opfilter_studies/prodgenie_nue_cc_uniform_flux_uboone.fcl

# %% [markdown]
# **FHiCL search path:**

# %%
echo $FHICL_FILE_PATH
# Out:
# .:./job:/cvmfs/uboone.opensciencegrid.org/products/uboonecode/v07_07_01_02/job:/cvmfs/uboone.opensciencegrid.org/products/ubutil/v07_07_01/job:/cvmfs/uboone.opensciencegrid.org/products/ublite/v07_07_01/job:/cvmfs/uboone.opensciencegrid.org/products/ubana/v07_07_01/job:/cvmfs/uboone.opensciencegrid.org/products/ubraw/v07_07_01/job:/cvmfs/uboone.opensciencegrid.org/products/ubreco/v07_07_01/job:/cvmfs/uboone.opensciencegrid.org/products/ubsim/v07_07_01/job:/cvmfs/uboone.opensciencegrid.org/products/ubcrt/v07_07_01/job:/cvmfs/uboone.opensciencegrid.org/products/ubcv/v07_07_01/job:/cvmfs/uboone.opensciencegrid.org/products/ubevt/v07_07_01/job:/cvmfs/uboone.opensciencegrid.org/products/ubcore/v07_07_01/job:/cvmfs/uboone.opensciencegrid.org/products/ubobj/v07_07_01/job:.:./job:/cvmfs/larsoft.opensciencegrid.org/products/larwirecell/v07_02_01/fcl:/cvmfs/larsoft.opensciencegrid.org/products/larpandora/v07_01_08/job:/cvmfs/larsoft.opensciencegrid.org/products/larg4/v07_01_06/fcl:/cvmfs/larso
# ...

# %% [markdown]
# **FHiCL dump of my fcl file. Here I'm trying to use flux type "function" to be flat (="1") from 0.1 GeV to 0.6 GeV. Note beam center, direction, and radius seem ok.**

# %%
fhicl-dump prodgenie_nue_cc_uniform_flux_uboone.fcl
# Out:
# # Produced from 'fhicl-dump' using:
# #   Input  : prodgenie_nue_cc_uniform_flux_uboone.fcl
# #   Policy : cet::filepath_maker
# #   Path   : "FHICL_FILE_PATH"
#
# outputs: {
#    out1: {
#       compressionLevel: 1
#       dataTier: "generated"
#       fileName: "prodgenie_nue_cc_uniform_flux_uboone_%tc_gen.root"
#       module_type: "RootOutput"
#    }
# }
# physics: {
#    end_paths: [
#       "stream1"
#    ]
#    producers: {
#       generator: {
#          BeamCenter: [
#             -1400,
#             -350,
#             0
#          ]
#          BeamDirection: [
#             0,
#             0,
#             1
#          ]
#          BeamName: "booster"
#          BeamRadius: 3
#          DebugFlags: 0
#          DefinedVtxHistRange: false
#          DetectorLocation: "MINOS-NearDet"
#          Environment: [
#             "GPRODMODE",
#             "YES"
#          ]
#          EventGeneratorList: "CCinclMEC"
#          EventsPerSpill: 0
#          FiducialCut: "none"
# ...

# %% [markdown]
# **Here's a similar FHiCL dump for a generation that works, using "simple_flux" ont the flux type. Beam center, direction, and radius look the same as before.**

# %%
fhicl-dump prodgenie_bnb_intrinsic_nue_uboone.fcl
# Out:
# # Produced from 'fhicl-dump' using:
# #   Input  : prodgenie_bnb_intrinsic_nue_uboone.fcl
# #   Policy : cet::filepath_maker
# #   Path   : "FHICL_FILE_PATH"
#
# outputs: {
#    out1: {
#       compressionLevel: 1
#       dataTier: "generated"
#       fileName: "prodgenie_bnb_intrinsic_nue_uboone_%tc_gen.root"
#       module_type: "RootOutput"
#    }
# }
# physics: {
#    end_paths: [
#       "stream1"
#    ]
#    producers: {
#       generator: {
#          BeamCenter: [
#             -1400,
#             -350,
#             0
#          ]
#          BeamDirection: [
#             0,
#             0,
#             1
#          ]
#          BeamName: "booster"
#          BeamRadius: 3
#          DebugFlags: 0
#          DefinedVtxHistRange: false
#          DetectorLocation: "MINOS-NearDet"
#          Environment: [
#             "GPRODMODE",
#             "YES"
#          ]
#          EventGeneratorList: "CCinclMEC"
#          EventsPerSpill: 0
#          FiducialCut: "none"
# ...
