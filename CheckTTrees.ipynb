// %%
TFile f("opfilterana.root")
// Out:
// (TFile &) Name: opfilterana.root Title:

// %%
f.ls()
// Out:
// TFile**		opfilterana.root
//  TFile*		opfilterana.root
//   KEY: TDirectoryFile	saturation;1	saturation (OpDigitSaturationCorrection) folder
//   KEY: TDirectoryFile	nuana;1	nuana (MCNeutrinoAna) folder
//   KEY: TDirectoryFile	opfilterana;1	opfilterana (UbooneOpticalFilterAna) folder
//   KEY: TH1D	FRH;1	FRH
//   KEY: TH1D	FRV;1	FRV
//   KEY: TH1D	rICKR;1	rICKR
//   KEY: TH1D	rICKI;1	rICKI
//   KEY: TH1D	PreC;1	PreC
//   KEY: TH1D	PostC;1	PostC
//   KEY: TH1D	PostO;1	PostO
//   KEY: TH1D	PreD;1	PreD
//   KEY: TH1D	PostDO;1	PostDO
//   KEY: TH1D	ER;1	ER

// %%
opfilterana->ls()
// Out:
// TDirectoryFile*		opfilterana	opfilterana (UbooneOpticalFilterAna) folder
//  KEY: TTree	opfilter_anatree;1	UbooneOpticalFilter Ana Tree

// %%
opfilterana->cd()
// Out:
// (bool) true

// %%
TCanvas c("c")
// Out:
// (TCanvas &) Name: c Title:

// %%
opfilter_anatree->Draw("pe_beam:pe_veto","1","colz");
c.Draw()

// %%
opfilter_anatree->Draw("pe_beam","pe_beam<100");
c.Draw()

// %%
f.cd()
// Out:
// (bool) true

// %%
nuana->ls()
// Out:
// TDirectoryFile*		nuana	nuana (MCNeutrinoAna) folder
//  KEY: TTree	mctruth_tree;1	MCTruth Tree
//  KEY: TTree	particle_tree;1	MCParticle Tree

// %%
nuana->cd()
// Out:
// (bool) true

// %%
mctruth_tree->Draw("mode");
c.Draw()
